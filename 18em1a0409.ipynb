# %% [markdown]
# ### matplot library

# %%
from matplotlib import pyplot as plt
x =[2,4,6,8,10,12,14,16]
y =[1,2,3,5,3,7,2,20]
plt.bar(x,y)
plt.show()

# %%
from matplotlib import pyplot as plt
x =[2,4,6,8,10,12,14,16]
y =[1,2,3,5,3,7,2,20]
plt.pie(x,y)
plt.show()

# %%
from matplotlib import pyplot as plt
x =[2,4,6,8,10,12,14,16]
y =[1,2,3,5,3,7,2,20]
plt.pie(x)
plt.show()

# %%
from matplotlib import pyplot as plt
x =[2,4,6,8,10,12,14,16]
y =[1,2,3,5,3,7,2,20]
plt.scatter(x,y)
plt.show()

# %%
from matplotlib import pyplot as plt
from matplotlib import image as img
im = img.imread("suji.jpg")
plt.imshow(im)
